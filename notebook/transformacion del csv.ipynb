# %% [markdown]
# # limpieza de columnas que no he utilizado

# %% [markdown]
# ## 1. subo el csv al jupiter

# %%
import pandas as pd

# %%
attrition = pd.read_csv('../Data/HRDataset_v14.csv')

# %% [markdown]
# ## 2. voy a eliminar todas las columnas que no he utilizado en la visualizacion

# %%
attrition.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
columnas_seleccionadas = ['Employee_Name', 'EmpID', 'Salary','Sex','RaceDesc','DateofHire','DateofTermination','TermReason','EmploymentStatus','Department','Absences']

# %%
attrition_cleaned = attrition[columnas_seleccionadas]

# %%
attrition_cleaned
# Out:
#                 Employee_Name  EmpID  Salary Sex RaceDesc DateofHire  \
# 0         Adinolfi, Wilson  K  10026   62506  M     White   7/5/2011
# 1    Ait Sidi, Karthikeyan     10084  104437  M     White  3/30/2015
# 2           Akinkuolie, Sarah  10196   64955   F    White   7/5/2011
# 3                Alagbe,Trina  10088   64991   F    White   1/7/2008
# 4            Anderson, Carol   10069   50825   F    White  7/11/2011
# ..                        ...    ...     ...  ..      ...        ...
# 306            Woodson, Jason  10135   65893  M     White   7/7/2014
# 307        Ybarra, Catherine   10301   48513   F    Asian   9/2/2008
# 308          Zamora, Jennifer  10010  220450   F    White  4/10/2010
# 309               Zhou, Julia  10043   89292   F    White  3/30/2015
# 310             Zima, Colleen  10271   45046   F    Asian  9/29/2014
#
#     DateofTermination         TermReason        EmploymentStatus  \
# 0                 NaN  N/A-StillEmployed                  Active
# ...

# %%
orden_deseado = ['EmpID','Employee_Name', 'EmploymentStatus', 'Sex','RaceDesc','Department','Salary','DateofHire','DateofTermination','TermReason','Absences']

# %%
attrition_cleaned = attrition_cleaned[orden_deseado]

# %%
attrition_cleaned
# Out:
#      EmpID             Employee_Name        EmploymentStatus Sex RaceDesc  \
# 0    10026       Adinolfi, Wilson  K                  Active  M     White
# 1    10084  Ait Sidi, Karthikeyan     Voluntarily Terminated  M     White
# 2    10196         Akinkuolie, Sarah  Voluntarily Terminated   F    White
# 3    10088              Alagbe,Trina                  Active   F    White
# 4    10069          Anderson, Carol   Voluntarily Terminated   F    White
# ..     ...                       ...                     ...  ..      ...
# 306  10135            Woodson, Jason                  Active  M     White
# 307  10301        Ybarra, Catherine   Voluntarily Terminated   F    Asian
# 308  10010          Zamora, Jennifer                  Active   F    White
# 309  10043               Zhou, Julia                  Active   F    White
# 310  10271             Zima, Colleen                  Active   F    Asian
#
#             Department  Salary DateofHire DateofTermination  \
# ...

# %%
#attrition_cleaned.to_csv('HHRR_tableau.csv', index=False)
